# %%
import os
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("fh_LDLR_clinvar_full.csv")
df.head()
# Out:
#    AlleleID                       Type  \
# 0     18722  single nucleotide variant
# 1     18722  single nucleotide variant
# 2     18724  single nucleotide variant
# 3     18724  single nucleotide variant
# 4     18725  single nucleotide variant
#
#                                        Name  GeneID GeneSymbol    HGNC_ID  \
# 0    NM_000527.5(LDLR):c.97C>T (p.Gln33Ter)    3949       LDLR  HGNC:6547
# 1    NM_000527.5(LDLR):c.97C>T (p.Gln33Ter)    3949       LDLR  HGNC:6547
# 2   NM_000527.5(LDLR):c.259T>G (p.Trp87Gly)    3949       LDLR  HGNC:6547
# 3   NM_000527.5(LDLR):c.259T>G (p.Trp87Gly)    3949       LDLR  HGNC:6547
# 4  NM_000527.5(LDLR):c.530C>T (p.Ser177Leu)    3949       LDLR  HGNC:6547
#
#   ClinicalSignificance  ClinSigSimple LastEvaluated  RS# (dbSNP)  \
# 0           Pathogenic              1  Mar 25, 2022    121908024
# 1           Pathogenic              1  Mar 25, 2022    121908024
# 2           Pathogenic              1  Jun 07, 2021    121908025
# ...

# %%
for col in df.columns:
    print(f"Feature: {col}")
    print(df[col].describe())
# Out:
# Feature: AlleleID
# count    9.088000e+03
# mean     1.174565e+06
# std      1.253288e+06
# min      1.872200e+04
# 25%      2.461220e+05
# 50%      4.348175e+05
# 75%      1.816336e+06
# max      4.798621e+06
# Name: AlleleID, dtype: float64
# Feature: Type
# count                          9088
# unique                            9
# top       single nucleotide variant
# freq                           6734
# Name: Type, dtype: object
# Feature: Name
# count              9088
# unique             4670
# top       Single allele
# freq                 27
# Name: Name, dtype: object
# Feature: GeneID
# count    9088.0
# mean     3949.0
# std         0.0
# min      3949.0
# 25%      3949.0
# 50%      3949.0
# 75%      3949.0
# max      3949.0
# Name: GeneID, dtype: float64
# Feature: GeneSymbol
# count     9088
# unique       1
# top       LDLR
# freq      9088
# Name: GeneSymbol, dtype: object
# Feature: HGNC_ID
# count          9088
# unique            1
# top       HGNC:6547
# ...

# %%
df.loc[df['VariationID']==694275]
# Out:
# Empty DataFrame
# Columns: [AlleleID, Type, Name, GeneID, GeneSymbol, HGNC_ID, ClinicalSignificance, ClinSigSimple, LastEvaluated, RS# (dbSNP), nsv/esv (dbVar), RCVaccession, PhenotypeIDS, PhenotypeList, Origin, OriginSimple, Assembly, ChromosomeAccession, Chromosome, Start, Stop, ReferenceAllele, AlternateAllele, Cytogenetic, ReviewStatus, NumberSubmitters, Guidelines, TestedInGTR, OtherIDs, SubmitterCategories, VariationID, PositionVCF, ReferenceAlleleVCF, AlternateAlleleVCF, SomaticClinicalImpact, SomaticClinicalImpactLastEvaluated, ReviewStatusClinicalImpact, Oncogenicity, OncogenicityLastEvaluated, ReviewStatusOncogenicity, SCVsForAggregateGermlineClassification, SCVsForAggregateSomaticClinicalImpact, SCVsForAggregateOncogenicityClassification]
# Index: []

# %%
df['RS# (dbSNP)'].value_counts()
# Out:
# RS# (dbSNP)
# -1             1237
#  879254976        6
#  879254685        6
#  773328511        6
#  757808215        6
#  879254668        6
#  875989933        6
#  875989934        6
#  779913921        6
#  753707206        6
#  875989926        6
#  875989928        6
#  875989931        6
#  537484504        6
#  879254913        6
#  879255051        6
#  2077311848       6
#  756880555        6
#  12710260         6
#  878854027        6
#  777188764        6
#  875989922        6
#  879254360        6
#  879255035        6
#  879255049        6
#  879254652        6
#  879254663        6
#  879254646        6
#  879255003        6
#  1344561983       6
#  2077272670       6
#  879254694        6
#  879254729        6
#  13306512         6
#  879254719        6
#  757252110        6
#  869320652        6
#  879254944        6
#  875989887        6
#  2228671          6
#  755389753        6
#  755667663        6
#  879255000        6
#  368978979        6
# ...

# %%
df.loc[(df['Assembly']=='na')].value_counts()
# Out:
# AlleleID  Type         Name                                                    GeneID  GeneSymbol  HGNC_ID    ClinicalSignificance    ClinSigSimple  LastEvaluated  RS# (dbSNP)  nsv/esv (dbVar)  RCVaccession  PhenotypeIDS                                                     PhenotypeList                      Origin     OriginSimple  Assembly  ChromosomeAccession  Chromosome  Start  Stop  ReferenceAllele  AlternateAllele  Cytogenetic  ReviewStatus                         NumberSubmitters  Guidelines                           TestedInGTR  OtherIDs                             SubmitterCategories  VariationID  PositionVCF  ReferenceAlleleVCF  AlternateAlleleVCF  SomaticClinicalImpact  SomaticClinicalImpactLastEvaluated  ReviewStatusClinicalImpact  Oncogenicity  OncogenicityLastEvaluated  ReviewStatusOncogenicity  SCVsForAggregateGermlineClassification  SCVsForAggregateSomaticClinicalImpact  SCVsForAggregateOncogenicityClassification
# ...

# %%
# remove columns with unique values
unique_cols = ['GeneID', 'GeneSymbol', 'HGNC_ID', 'ReferenceAllele', 'AlternateAllele', 'TestedInGTR', 'SomaticClinicalImpactLastEvaluated', 'OncogenicityLastEvaluated', 'SCVsForAggregateSomaticClinicalImpact', 'SCVsForAggregateOncogenicityClassification']
useless_cols = ['ChromosomeAccession']
useful_cols = ['ReferenceAlleleVCF']
